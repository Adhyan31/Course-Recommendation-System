# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df= pd.read_csv('udemy_courses.csv')

# %%
df.head()
# Out:
#    course_id  ...           subject
# 0    1070968  ...  Business Finance
# 1    1113822  ...  Business Finance
# 2    1006314  ...  Business Finance
# 3    1210588  ...  Business Finance
# 4    1011058  ...  Business Finance
#
# [5 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3678 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3678 non-null   int64
#  1   course_title         3678 non-null   object
#  2   url                  3678 non-null   object
#  3   is_paid              3678 non-null   bool
#  4   price                3678 non-null   int64
#  5   num_subscribers      3678 non-null   int64
#  6   num_reviews          3678 non-null   int64
#  7   num_lectures         3678 non-null   int64
#  8   level                3678 non-null   object
#  9   content_duration     3678 non-null   float64
#  10  published_timestamp  3678 non-null   object
#  11  subject              3678 non-null   object
# dtypes: bool(1), float64(1), int64(5), object(5)
# memory usage: 319.8+ KB

# %%
df.isna().sum()
# Out:
# course_id              0
# course_title           0
# url                    0
# is_paid                0
# price                  0
# num_subscribers        0
# num_reviews            0
# num_lectures           0
# level                  0
# content_duration       0
# published_timestamp    0
# subject                0
# dtype: int64

# %%
#Number of subjects in the dataset
df['subject'].value_counts()
# Out:
# Web Development        1200
# Business Finance       1195
# Musical Instruments     680
# Graphic Design          603
# Name: subject, dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.countplot(df['subject'])
plt.title('Number of each subject')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,5))
df['subject'].value_counts().plot(kind='pie')
plt.show()

# %%
#Number of subscribers per subject
df.groupby('subject')['num_subscribers'].sum()
# Out:
# subject
# Business Finance       1868711
# Graphic Design         1063148
# Musical Instruments     846689
# Web Development        7980572
# Name: num_subscribers, dtype: int64

# %%
#Plotting of number of subscribers per subject
df.groupby('subject')['num_subscribers'].sum().plot(kind='bar')

# %%
df.groupby('subject')['num_subscribers'].sum().plot(kind='pie')

# %%
df['num_subscribers'].sum()
# Out:
# 11759120

# %%
df['num_subscribers'].mean()
# Out:
# 3197.150625339859

# %%
df['num_subscribers'].min()
# Out:
# 0

# %%
df['num_subscribers'].max()
# Out:
# 268923

# %%
#course having highest number of subscribers
df['num_subscribers'].idxmax()
# Out:
# 2827

# %%
#get the location
df.iloc[2827]
# Out:
# course_id                                                          41295
# course_title                        Learn HTML5 Programming From Scratch
# url                    https://www.udemy.com/learn-html5-programming-...
# is_paid                                                            False
# price                                                                  0
# num_subscribers                                                   268923
# num_reviews                                                         8629
# num_lectures                                                          45
# level                                                         All Levels
# content_duration                                                    10.5
# published_timestamp                                 2013-02-14T07:03:41Z
# subject                                                  Web Development
# Name: 2827, dtype: object

# %%
df['level'].value_counts()
# Out:
# All Levels            1929
# Beginner Level        1270
# Intermediate Level     421
# Expert Level            58
# Name: level, dtype: int64

# %%
df['level'].value_counts().plot(kind='bar')

# %%
df['level'].value_counts().plot(kind='pie')

# %%
#number of subscribers per level
df.groupby('level')['num_subscribers'].sum()
# Out:
# level
# All Levels            6915076
# Beginner Level        4051843
# Expert Level            50196
# Intermediate Level     742005
# Name: num_subscribers, dtype: int64

# %%
#number of subscribers per level
df.groupby('level')['num_subscribers'].sum().plot(kind='bar')

# %%
#number of subscribers per level
df.groupby('level')['num_subscribers'].sum().plot(kind='pie')

# %%
#levels per subject category
df.groupby('subject')['level'].value_counts()
# Out:
# subject              level
# Business Finance     All Levels            696
#                      Beginner Level        340
#                      Intermediate Level    128
#                      Expert Level           31
# Graphic Design       All Levels            298
#                      Beginner Level        243
#                      Intermediate Level     57
#                      Expert Level            5
# Musical Instruments  Beginner Level        296
#                      All Levels            276
#                      Intermediate Level    101
#                      Expert Level            7
# Web Development      All Levels            659
#                      Beginner Level        391
#                      Intermediate Level    135
#                      Expert Level           15
# Name: level, dtype: int64

# %%
#levels per subject category
df.groupby('subject')['level'].value_counts().plot(kind='bar')

# %%
#lplot evels per subject category
plt.figure(figsize=(20,10))
sns.barplot(x='level', y='num_subscribers', hue='subject', data=df, ci=None)
plt.show()

# %%
df.head()
# Out:
#    course_id  ...           subject
# 0    1070968  ...  Business Finance
# 1    1113822  ...  Business Finance
# 2    1006314  ...  Business Finance
# 3    1210588  ...  Business Finance
# 4    1011058  ...  Business Finance
#
# [5 rows x 12 columns]

# %%
#lplot evels per subject category
plt.figure(figsize=(20,10))
sns.barplot(x='level', y='num_lectures', hue='subject', data=df, ci=None)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='level', y='num_reviews', hue='subject', data=df, ci=None)
plt.show()

# %%
#EDA on price
df['price'].unique()
# Out:
# array([200,  75,  45,  95, 150,  65, 195,  30,  20,  50, 175, 140, 115,
#        190, 125,  60, 145, 105, 155, 185, 180, 120,  25, 160,  40,   0,
#        100,  90,  35,  80,  70,  55, 165, 130,  85, 170, 110, 135])

# %%
df['price'].mean()
# Out:
# 66.0494834148994

# %%
df['price'].max()
# Out:
# 200

# %%
df['price'].idxmax()
# Out:
# 0

# %%
df.iloc[0]
# Out:
# course_id                                                        1070968
# course_title                          Ultimate Investment Banking Course
# url                    https://www.udemy.com/ultimate-investment-bank...
# is_paid                                                             True
# price                                                                200
# num_subscribers                                                     2147
# num_reviews                                                           23
# num_lectures                                                          51
# level                                                         All Levels
# content_duration                                                     1.5
# published_timestamp                                 2017-01-18T20:58:58Z
# subject                                                 Business Finance
# Name: 0, dtype: object

# %%
#most profitable course
df['profit']=df['price']*df['num_subscribers']

# %%
df['profit']
# Out:
# 0       429400
# 1       209400
# 2        97830
# 3       232845
# 4       255200
#          ...
# 3673    104000
# 3674      7650
# 3675     20520
# 3676     15000
# 3677     40545
# Name: profit, Length: 3678, dtype: int64

# %%
df['profit'].max()
# Out:
# 24316800

# %%
df['profit'].idxmax()
# Out:
# 3230

# %%
df.iloc[3230]
# Out:
# course_id                                                         625204
# course_title                                  The Web Developer Bootcamp
# url                    https://www.udemy.com/the-web-developer-bootcamp/
# is_paid                                                             True
# price                                                                200
# num_subscribers                                                   121584
# num_reviews                                                        27445
# num_lectures                                                         342
# level                                                         All Levels
# content_duration                                                      43
# published_timestamp                                 2015-11-02T21:13:27Z
# subject                                                  Web Development
# profit                                                          24316800
# Name: 3230, dtype: object

# %%
#courses on udemy paid or free
df['is_paid'].value_counts()
# Out:
# True     3368
# False     310
# Name: is_paid, dtype: int64

# %%
sns.countplot(df['is_paid'])

# %%
#paid or free courses per subject
df.groupby('is_paid')['subject'].value_counts()
# Out:
# is_paid  subject
# False    Web Development         133
#          Business Finance         96
#          Musical Instruments      46
#          Graphic Design           35
# True     Business Finance       1099
#          Web Development        1067
#          Musical Instruments     634
#          Graphic Design          568
# Name: subject, dtype: int64

# %%
#lplot evels per subject category
plt.figure(figsize=(20,10))
sns.barplot(x='level', y='is_paid', hue='subject', data=df, ci=None)
plt.show()

# %%
#correlation
sns.scatterplot(x='price', y='num_subscribers', data=df)

# %%
sns.scatterplot(x='price', y='num_reviews', data=df)

# %%
plt.figure(figsize=(20,10))
plt.title('Does price influence subscription per subject area')
sns.lineplot(x='price', y='num_subscribers', hue='subject', data=df, ci=None)
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.title('Does reviews influence subscription per subject area')
sns.lineplot(x='num_reviews', y='num_subscribers', hue='subject', data=df, ci=None)
plt.show()

# %%
df.head()
# Out:
#    course_id  ...  profit
# 0    1070968  ...  429400
# 1    1113822  ...  209400
# 2    1006314  ...   97830
# 3    1210588  ...  232845
# 4    1011058  ...  255200
#
# [5 rows x 13 columns]

# %%
df['published_date']=df['published_timestamp'].str.split('T').str.get(0)

# %%
df['published_date']
# Out:
# 0       2017-01-18
# 1       2017-03-09
# 2       2016-12-19
# 3       2017-05-30
# 4       2016-12-13
#            ...
# 3673    2016-06-14
# 3674    2017-03-10
# 3675    2015-12-30
# 3676    2016-08-11
# 3677    2014-09-28
# Name: published_date, Length: 3678, dtype: object

# %%
from datetime import datetime
def convert_to_dt(x):
  mydate= datetime.strptime(x, '%Y-%m-%d')
  result= mydate.strftime('%Y-%m-%d')
  return result

# %%
convert_to_dt('2017-01-18')
# Out:
# '2017-01-18'

# %%
df['published_date']=df['published_date'].apply(lambda x:convert_to_dt(x))

# %%
df.dtypes
# Out:
# course_id                int64
# course_title            object
# url                     object
# is_paid                   bool
# price                    int64
# num_subscribers          int64
# num_reviews              int64
# num_lectures             int64
# level                   object
# content_duration       float64
# published_timestamp     object
# subject                 object
# profit                   int64
# published_date          object
# dtype: object

# %%
df['published_date']=pd.to_datetime(df['published_date'], format='%Y-%m-%d')

# %%
df.dtypes
# Out:
# course_id                       int64
# course_title                   object
# url                            object
# is_paid                          bool
# price                           int64
# num_subscribers                 int64
# num_reviews                     int64
# num_lectures                    int64
# level                          object
# content_duration              float64
# published_timestamp            object
# subject                        object
# profit                          int64
# published_date         datetime64[ns]
# dtype: object

# %%
df['year']=df['published_date'].dt.year
df['month']=df['published_date'].dt.month
df['day']=df['published_date'].dt.day

# %%
df.groupby('year')['num_subscribers'].value_counts()
# Out:
# year  num_subscribers
# 2011  3697               1
#       7014               1
#       12458              1
#       26673              1
#       69186              1
#                         ..
# 2017  15276              1
#       16158              1
#       16829              1
#       17784              1
#       26742              1
# Name: num_subscribers, Length: 2893, dtype: int64

# %%
plt.figure(figsize=(20,10))
plt.title('Plot of subscription per year per subject area')
sns.lineplot(x='year', y='num_subscribers', hue='subject', data=df, ci=None)
plt.show()
